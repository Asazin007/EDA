# %% [markdown]
# <a href="https://colab.research.google.com/github/Asazin007/EDA/blob/main/ExploratoryDataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# ### Sub-Task 1:

# %% [markdown]
# 1. Data Loading and Initial Inspection:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
client_data = pd.read_csv('client_data.csv')
price_data = pd.read_csv('price_data.csv')

# %%
client_data.head(5)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
# 3      1584             0                0  2010-03-30  2016-03-30
# 4      4425             0              526  2010-01-13  2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# ...

# %%
price_data.head(5)
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
# 3  038af19179925da21a25619c5a24b745  2015-04-01            0.149626
# 4  038af19179925da21a25619c5a24b745  2015-05-01            0.149626
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
# 3             0.0                 0.0           44.266931             0.0
# 4             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0
# ...

# %% [markdown]
# 2. Data Overview:

# %%
print("Client Data Info:")
print(client_data.info())

print("\nPrice Data Info:")
print(price_data.info())
# Out:
# Client Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  object
#  1   channel_sales                   14606 non-null  object
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  object
#  6   date_end                        14606 non-null  object
#  7   date_modif_prod                 14606 non-null  object
#  8   date_renewal                    14606 non-null  object
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
#  11  forecast_discount_energy        14606 non-null  float64
# ...

# %% [markdown]
# 3. Missing Values:

# %%
# Check for missing values in client_data
missing_client_data = client_data.isnull().sum()

# Check for missing values in price_data
missing_price_data = price_data.isnull().sum()

# Display missing values counts
print("Missing Values in Client Data:")
print(missing_client_data)

print("\nMissing Values in Price Data:")
print(missing_price_data)
# Out:
# Missing Values in Client Data:
# id                                0
# channel_sales                     0
# cons_12m                          0
# cons_gas_12m                      0
# cons_last_month                   0
# date_activ                        0
# date_end                          0
# date_modif_prod                   0
# date_renewal                      0
# forecast_cons_12m                 0
# forecast_cons_year                0
# forecast_discount_energy          0
# forecast_meter_rent_12m           0
# forecast_price_energy_off_peak    0
# forecast_price_energy_peak        0
# forecast_price_pow_off_peak       0
# has_gas                           0
# imp_cons                          0
# margin_gross_pow_ele              0
# margin_net_pow_ele                0
# nb_prod_act                       0
# net_margin                        0
# num_years_antig                   0
# origin_up                         0
# pow_max                           0
# ...

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=(12,6)

# %%
sns.heatmap(price_data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# 4. Summary Statistics:

# %%
# Summary statistics for client_data
client_data_description = client_data.describe()

# Summary statistics for price_data
price_data_description = price_data.describe()

# Display summary statistics
print("Summary Statistics for Client Data:")
client_data_description

print("\nSummary Statistics for Price Data:")
print(price_data_description)
# Out:
# Summary Statistics for Client Data:
#
# Summary Statistics for Price Data:
#        price_off_peak_var  price_peak_var  price_mid_peak_var  \
# count       193002.000000   193002.000000       193002.000000
# mean             0.141027        0.054630            0.030496
# std              0.025032        0.049924            0.036298
# min              0.000000        0.000000            0.000000
# 25%              0.125976        0.000000            0.000000
# 50%              0.146033        0.085483            0.000000
# 75%              0.151635        0.101673            0.072558
# max              0.280700        0.229788            0.114102
#
#        price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# count       193002.000000   193002.000000       193002.000000
# mean            43.334477       10.622875            6.409984
# std              5.410297       12.841895            7.773592
# min              0.000000        0.000000            0.000000
# ...

# %% [markdown]
# 5.Mearge datasets

# %%
df=pd.merge(client_data,price_data,on='id',how='left')

# %%
df.head(5)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 2  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 3  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 4  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1         0         54946                0  2013-06-15  2016-06-15
# 2         0         54946                0  2013-06-15  2016-06-15
# 3         0         54946                0  2013-06-15  2016-06-15
# 4         0         54946                0  2013-06-15  2016-06-15
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  \
# 0      2015-11-01   2015-06-23                0.0  ...
# ...

# %%
df.dtypes
# Out:
# id                                 object
# channel_sales                      object
# cons_12m                            int64
# cons_gas_12m                        int64
# cons_last_month                     int64
# date_activ                         object
# date_end                           object
# date_modif_prod                    object
# date_renewal                       object
# forecast_cons_12m                 float64
# forecast_cons_year                  int64
# forecast_discount_energy          float64
# forecast_meter_rent_12m           float64
# forecast_price_energy_off_peak    float64
# forecast_price_energy_peak        float64
# forecast_price_pow_off_peak       float64
# has_gas                            object
# imp_cons                          float64
# margin_gross_pow_ele              float64
# margin_net_pow_ele                float64
# nb_prod_act                         int64
# net_margin                        float64
# ...

# %% [markdown]
# 6.variable distributions

# %%
df.columns
# Out:
# Index(['id', 'channel_sales', 'cons_12m', 'cons_gas_12m', 'cons_last_month',
#        'date_activ', 'date_end', 'date_modif_prod', 'date_renewal',
#        'forecast_cons_12m', 'forecast_cons_year', 'forecast_discount_energy',
#        'forecast_meter_rent_12m', 'forecast_price_energy_off_peak',
#        'forecast_price_energy_peak', 'forecast_price_pow_off_peak', 'has_gas',
#        'imp_cons', 'margin_gross_pow_ele', 'margin_net_pow_ele', 'nb_prod_act',
#        'net_margin', 'num_years_antig', 'origin_up', 'pow_max', 'churn',
#        'price_date', 'price_off_peak_var', 'price_peak_var',
#        'price_mid_peak_var', 'price_off_peak_fix', 'price_peak_fix',
#        'price_mid_peak_fix'],
#       dtype='object')

# %%
# define a function to plot bar chart to display a feature's distribution with percent labels.
def plot_bar_chart_with_percent_label(df, target_variable, if_sort=False, gap_label_bar=0, figsize=(9,6)):
    # prepare data
    plot_data = client_data[[target_variable]].value_counts().reset_index(name='count')
    plot_data['percent'] = plot_data['count']/plot_data['count'].sum()
    if if_sort:
        x_order = plot_data.sort_values(by=['percent'], ascending=False)[target_variable]
    else:
        x_order = plot_data.sort_values(by=[target_variable], ascending=True)[target_variable]
    # plot
    fig = plt.figure(figsize=figsize)
    ax = sns.barplot(data=plot_data, x=target_variable, y='percent', order=x_order)
    # add label
    for p in ax.patches:
        x = p.get_x() + p.get_width()/2
        y = p.get_height() + gap_label_bar
        ax.annotate(text='{:.2f}%'.format(p.get_height()*100), xy=(x, y), ha='center')
    ax.margins(y=0.1)
    # plot stacked bar chart with percent label by churn
def plot_stacked_bar_with_percent_label_by_churn(df, target_variable, if_sort=False, figsize=(9,6)):
    plot_data = df.groupby([target_variable,'churn']).size().reset_index(name='count')
    plot_data = plot_data.pivot(index=target_variable, columns='churn', values='count').fillna(0)
    plot_data = plot_data.div(plot_data.sum(axis=1), axis=0)
    if if_sort:
        plot_data = plot_data.sort_values(by=[0])
    ax = plot_data.plot(kind='bar', rot=False, stacked=True, figsize=figsize)
    plt.legend(['stay', 'switch'], loc='upper center', ncol=2)
    # add label
    for p in ax.patches:
        percentage = '{:.1f}%'.format(p.get_height()*100)
        if percentage!='0.0%':
            x = p.get_x() + p.get_width()/2
            y = 1 - p.get_height()/1.8
            ax.annotate(text=percentage, xy=(x, y), ha='center')
    ax.margins(y=0.1)

# %%
plot_bar_chart_with_percent_label(df=client_data, target_variable='churn', gap_label_bar=0.02)

# %% [markdown]
# Observation: Around 9.72% of the customers change their providers.

# %%
plot_bar_chart_with_percent_label(df=client_data, target_variable='channel_sales', if_sort=True, gap_label_bar=0.01)

# %% [markdown]
# Type 4 is the most common sales channel. Type 1, 3 and 6 sales channels are very rare.

# %% [markdown]
# Creating new columns with just the year data

# %%
date_df = client_data.iloc[:,5:9]

# %%
def year_from_date(data):
    # Iterate through all columns in the DataFrame
    for column in data.columns:
        # Check if the column is of datetime type
        if pd.api.types.is_datetime64_any_dtype(data[column]):
            # Extract the year and create a new column
            data[column + '_year'] = data[column].dt.year
    return data.head()

year_from_date(date_df)
# Out:
#    date_activ    date_end date_modif_prod date_renewal
# 0  2013-06-15  2016-06-15      2015-11-01   2015-06-23
# 1  2009-08-21  2016-08-30      2009-08-21   2015-08-31
# 2  2010-04-16  2016-04-16      2010-04-16   2015-04-17
# 3  2010-03-30  2016-03-30      2010-03-30   2015-03-31
# 4  2010-01-13  2016-03-07      2010-01-13   2015-03-09

# %%
sns.histplot(data=date_df, x='date_activ', bins=50, kde=True)
plt.title('date of activation of the contract')
plt.xlabel('date of activation of the contract')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
price_data.hist(bins=20, figsize=(20,15))
plt.show()

# %%
# Example: Visualize the distribution of 'cons_12m'
plt.figure(figsize=(10, 6))
sns.histplot(data=client_data, x='cons_12m', bins=50, kde=True)
plt.title('Electricity Consumption (cons_12m) Distribution')
plt.xlabel('Electricity Consumption (cons_12m)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Observation: Electricity consumption over past 12 months in decresing exponensially.

# %%
# Visualize the distribution of 'forecast_cons_12m'
plt.figure(figsize=(10, 6))
sns.histplot(data=client_data, x='forecast_cons_12m', bins=50, kde=True)
plt.title('Forecasted Electricity Consumption (forecast_cons_12m) Distribution')
plt.xlabel('Forecasted Electricity Consumption (forecast_cons_12m)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Observation: Electricity consumption over past  months in decresing exponensially.

# %%
# Visualize the distribution of 'num_years_antig'
plt.figure(figsize=(8, 6))
sns.histplot(data=client_data, x='num_years_antig', bins=20, kde=True)
plt.title('Antiquity of Clients (num_years_antig) Distribution')
plt.xlabel('Antiquity of Clients (num_years_antig)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Observation : Antiquity of clients are mostly from 4 to 6 years.

# %%
sns.histplot(data=client_data, x='imp_cons', bins=80, kde=True)
plt.title('current paid consumption Distribution')
plt.xlabel('current paid consumption')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Obsevation:Current paid cunsumption is also decreasing

# %% [markdown]
# ## **Sub-Task 2:**

# %% [markdown]
# Calculating Price Sensitivity:

# %%
stat_ = ['max', 'min', 'mean']
price_attr = ['price_off_peak_var','price_peak_var','price_mid_peak_var','price_off_peak_fix','price_peak_fix','price_mid_peak_fix']
price_stat = price_data.drop(columns=['price_date']).groupby(['id']).agg({'price_off_peak_var': stat_, 'price_peak_var': stat_, 'price_mid_peak_var': stat_,
                                                      'price_off_peak_fix': stat_, 'price_peak_fix': stat_, 'price_mid_peak_fix': stat_,})
# flatten the column names
price_stat.columns = ['_'.join(x) for x in zip(price_stat.columns.get_level_values(0), price_stat.columns.get_level_values(1))]
price_stat = price_stat.reset_index()
price_stat.head(3)
# Out:
#                                  id  price_off_peak_var_max  \
# 0  0002203ffbb812588b632b9e628cc38d                0.128067
# 1  0004351ebdd665e6ee664792efc4fd13                0.148405
# 2  0010bcc39e42b3c2131ed2ce55246e3c                0.205742
#
#    price_off_peak_var_min  price_off_peak_var_mean  price_peak_var_max  \
# 0                0.119906                 0.124338            0.105842
# 1                0.143943                 0.146426            0.000000
# 2                0.150837                 0.181558            0.000000
#
#    price_peak_var_min  price_peak_var_mean  price_mid_peak_var_max  \
# 0            0.101673             0.103794                0.073773
# 1            0.000000             0.000000                0.000000
# 2            0.000000             0.000000                0.000000
#
#    price_mid_peak_var_min  price_mid_peak_var_mean  price_off_peak_fix_max  \
# 0                0.070232                  0.07316               40.728885
# ...

# %% [markdown]
# Merge client dataset to the above dataset to add churn data

# %%
# add churn values
price_stat = price_stat.merge(client_data[['id','churn']], on=['id'], how='left')
# drop ids that are not inclued in the price dataset
price_stat = price_stat.dropna(subset=['churn']).reset_index(drop=True)
price_stat.head(3)
# Out:
#                                  id  price_off_peak_var_max  \
# 0  0002203ffbb812588b632b9e628cc38d                0.128067
# 1  0004351ebdd665e6ee664792efc4fd13                0.148405
# 2  0010bcc39e42b3c2131ed2ce55246e3c                0.205742
#
#    price_off_peak_var_min  price_off_peak_var_mean  price_peak_var_max  \
# 0                0.119906                 0.124338            0.105842
# 1                0.143943                 0.146426            0.000000
# 2                0.150837                 0.181558            0.000000
#
#    price_peak_var_min  price_peak_var_mean  price_mid_peak_var_max  \
# 0            0.101673             0.103794                0.073773
# 1            0.000000             0.000000                0.000000
# 2            0.000000             0.000000                0.000000
#
#    price_mid_peak_var_min  price_mid_peak_var_mean  price_off_peak_fix_max  \
# 0                0.070232                  0.07316               40.728885
# ...

# %% [markdown]
# Calculate the biggest changes in prices over the whole year.

# %%
for attr in price_attr:
    price_stat[f'diff_max_min_{attr}'] = price_stat[f'{attr}_max'] - price_stat[f'{attr}_min']
price_stat.head(3)
# Out:
#                                  id  price_off_peak_var_max  \
# 0  0002203ffbb812588b632b9e628cc38d                0.128067
# 1  0004351ebdd665e6ee664792efc4fd13                0.148405
# 2  0010bcc39e42b3c2131ed2ce55246e3c                0.205742
#
#    price_off_peak_var_min  price_off_peak_var_mean  price_peak_var_max  \
# 0                0.119906                 0.124338            0.105842
# 1                0.143943                 0.146426            0.000000
# 2                0.150837                 0.181558            0.000000
#
#    price_peak_var_min  price_peak_var_mean  price_mid_peak_var_max  \
# 0            0.101673             0.103794                0.073773
# 1            0.000000             0.000000                0.000000
# 2            0.000000             0.000000                0.000000
#
#    price_mid_peak_var_min  price_mid_peak_var_mean  ...  \
# 0                0.070232                  0.07316  ...
# ...

# %% [markdown]
# Most cutomers' prices did not change much and kept stable.

# %%
def plot_histogram_by_churn(df, target_variable, figsize=(20,5), bins=100, if_churn=True):
    fig = plt.figure(figsize=figsize)
    if if_churn:
        ax = sns.histplot(data=df, x=target_variable, bins=bins, hue='churn')
    else:
        ax = sns.histplot(data=df, x=target_variable, bins=bins)

# %%
for attr in price_attr:
    plot_histogram_by_churn(df=price_stat, target_variable=f'diff_max_min_{attr}', if_churn=True)

# %% [markdown]
# Let's view price dataset
#
# We can see not all customers have the same number of price records. The vast majority of customers have 12 price reocrds and very few customers has less than 12 records

# %%
price_data['id'].value_counts().value_counts()
# Out:
# 12    15990
# 11       83
# 10       11
# 9         6
# 8         3
# 7         3
# Name: id, dtype: int64

# %%
price_data['price_date'].value_counts()
# Out:
# 2015-08-01    16094
# 2015-12-01    16094
# 2015-07-01    16090
# 2015-11-01    16087
# 2015-06-01    16085
# 2015-10-01    16085
# 2015-02-01    16082
# 2015-09-01    16082
# 2015-05-01    16080
# 2015-04-01    16079
# 2015-03-01    16074
# 2015-01-01    16070
# Name: price_date, dtype: int64

# %%
for attr in ['forecast_meter_rent_12m', 'forecast_price_energy_off_peak', 'forecast_price_energy_peak', 'forecast_price_pow_off_peak',]:
    plot_histogram_by_churn(df=client_data, target_variable=attr)

# %% [markdown]
# **Key Findings:**
#
# 1. **Churn Rate**: The churn rate is approximately 9.72%, indicating that about 9.72% of customers changed providers during the period under consideration.
#
# 2. **Skewed Consumption Data**: Numeric variables related to consumption, such as electricity and gas consumption, exhibit high skewness. This suggests that there may be a subset of customers with significantly different consumption patterns compared to the majority.
#
# 3. **Price Sensitivity**: Initial analysis does not show a strong correlation between changes in prices and customer churn. Price changes alone may not be the primary driver of churn in this dataset.
#
# **Suggestions for Data Augmentation:**
#
# 1. **Competitor Price Data**: Obtain data on pricing strategies and offers from competitors in the energy market. Analyzing competitor pricing can provide insights into how the client's prices compare and whether customers are switching due to better offers from competitors.
#
# 2. **Customer Feedback and Satisfaction Data**: Collect and integrate data on customer feedback and satisfaction. Customer surveys, reviews, and feedback can reveal valuable insights into the reasons for churn beyond pricing, such as customer service quality, billing issues, or other factors affecting satisfaction.
#
# 3. **Economic and Market Data**: Incorporate economic indicators and market trends data. Economic factors, such as changes in unemployment rates or energy market trends, can impact customer decisions to switch providers. Open-source economic datasets can be useful for this purpose.
#
# 4. **Demographic Information**: Gather demographic data about customers, including age, income, location, and household size. Demographic information can help segment customers and identify specific groups more prone to churn, enabling more targeted retention strategies.
#
# 5. **Social Media and Online Reviews**: Analyze social media sentiment and online reviews related to the client and competitors. Social listening tools can provide insights into public sentiment, complaints, and issues that may influence churn decisions.
#
# 6. **Energy Consumption Patterns**: Explore more detailed data on energy consumption patterns, including hourly or daily consumption data. This can help identify specific usage behaviors that correlate with churn.
#
# 7. **Customer Interaction Logs**: Access records of customer interactions with the client's customer support, including call logs and chat transcripts. Analyzing these interactions can reveal common customer concerns and pain points.
#
# 8. **Regulatory Changes**: Monitor and include data on energy market regulatory changes. Changes in regulations can impact pricing structures and customer behavior.
#
# By augmenting the existing dataset with these additional data sources, we can enhance our understanding of customer churn drivers and develop more effective retention strategies. Combining internal data with external sources and open-source datasets will provide a comprehensive view of the factors influencing churn in the energy market.
